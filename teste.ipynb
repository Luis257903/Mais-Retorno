# %%
import pandas as pd

df_test = pd.read_parquet("dados_parquet/fundos_202401.parquet")
df_test.columns
# Out:
# Index(['CNPJ', 'DATA', 'COTA', 'PATRIMÔNIO LÍQUIDO', 'CAPTAÇÃO', 'RESGATES',
#        'NÚMERO DE COTISTAS'],
#       dtype='object')
